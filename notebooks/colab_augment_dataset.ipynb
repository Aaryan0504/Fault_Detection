# %% [markdown]
# # Run `scripts/augment.py` on Google Colab
#
# Use this if your **raw** images and labels live in Colab/Drive (`data/raw/...`) and you want to build `data/augmented/` and refresh `dataset.yaml` **on the VM**.
#
# **Runtime:** CPU is usually enough for augmentation; training should use a **GPU** runtime (see `colab_train_yolo_obb.ipynb`). **TPU does not help** this script.
#
# If you already ran `augment.py` on your PC and only need training in Colab, skip this notebook and upload `data/augmented/` + `dataset.yaml`.

# %%
try:
    from google.colab import drive
    drive.mount("/content/drive")
except ImportError:
    pass

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path("/content/drive/MyDrive/ups_yolo")  # EDIT
os.chdir(PROJECT_ROOT)
print(Path.cwd())

# %%
# !pip install -q albumentations opencv-python-headless "numpy>=1.26,<2" matplotlib Pillow tqdm pyyaml scikit-learn

# %%
# !python scripts/augment.py
